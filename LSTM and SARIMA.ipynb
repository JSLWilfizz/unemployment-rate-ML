# %%
import pandas as pd

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams

from statsmodels.tsa.stattools import adfuller
# !pip install pmdarima --quiet
import pmdarima as pm

# %%
df = pd.read_csv("Datos_imputados_data_2.csv")[:-3]

#string to date format
df['Fecha'] = pd.to_datetime(df['Fecha'],infer_datetime_format=True)
df = df.set_index(['Fecha'])
df = df[["Tasa de desocupación "]]
df.head(5)
# Out:
#             Tasa de desocupación
# Fecha
# 2010-03-01               9.227598
# 2010-04-01               8.836054
# 2010-05-01               9.087731
# 2010-06-01               8.656064
# 2010-07-01               8.511179

# %%
plt.figure(figsize=(15,7))
plt.title("Tasa desocupación ")
plt.xlabel('Fecha')
plt.ylabel('Tasa')
plt.plot(df)
plt.show()

# %%
#Determine rolling statistics
df["rolling_avg"] = df["Tasa de desocupación "].rolling(window=12).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
df["rolling_std"] = df["Tasa de desocupación "].rolling(window=12).std()

#Plot rolling statistics
plt.figure(figsize=(15,7))
plt.plot(df["Tasa de desocupación "], color='#379BDB', label='Original')
plt.plot(df["rolling_avg"], color='#D22A0D', label='Rolling Mean')
plt.plot(df["rolling_std"], color='#142039', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
#Augmented Dickey–Fuller test:
print('Results of Dickey Fuller Test:')
dftest = adfuller(df["Tasa de desocupación "], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -2.257912
# p-value                          0.185902
# #Lags Used                      10.000000
# Number of Observations Used    144.000000
# Critical Value (1%)             -3.476598
# Critical Value (5%)             -2.881829
# Critical Value (10%)            -2.577589
# dtype: float64

# %% [markdown]
# ARIMA Y SARIMA

# %%
def forecast(ARIMA_model, periods=3):
    # Forecast
    n_periods = periods
    fitted, confint = ARIMA_model.predict(n_periods=n_periods, return_conf_int=True)
    index_of_fc = pd.date_range(df.index[-1] + pd.DateOffset(months=1), periods = n_periods, freq='MS')

    # make series for plotting purpose
    fitted_series = pd.Series(fitted, index=index_of_fc)
    lower_series = pd.Series(confint[:, 0], index=index_of_fc)
    upper_series = pd.Series(confint[:, 1], index=index_of_fc)

    # Plot
    plt.figure(figsize=(15,7))
    plt.plot(np.log(df["Tasa de desocupación "]), color='#1f76b4')
    plt.plot(fitted_series, color='darkgreen')
    plt.fill_between(lower_series.index, 
                    lower_series, 
                    upper_series, 
                    color='k', alpha=.15)

    plt.title("ARIMA/SARIMA - Predicción")
    plt.show()
    return fitted_series

# %%
#Standard ARIMA Model
ARIMA_model = pm.auto_arima(df["Tasa de desocupación "], 
                      start_p=1, 
                      start_q=1,
                      test='adf', # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=12, # frequency of series (if m==1, seasonal is set to FALSE automatically)
                      d=None,# let model determine 'd'
                      seasonal=True, # No Seasonality for standard ARIMA
                      trace=False, #logs 
                      error_action='warn', #shows errors ('ignore' silences these)
                      suppress_warnings=True,
                      stepwise=True)

# %%
ARIMA_model.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
# Seasonal - fit stepwise auto-ARIMA
SARIMA_model = pm.auto_arima(np.log(df["Tasa de desocupación "]), start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, 
                         m=12, #12 is the frequncy of the cycle
                         start_P=0, 
                         seasonal=True, #set to seasonal
                         d=None, 
                         D=1, #order of the seasonal differencing
                         trace=False,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

# %%
SARIMA_model.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
results_sa = forecast(SARIMA_model)

# %% [markdown]
# Testing

# %%
df2 = pd.read_csv("Datos_imputados_data_2.csv")[-3:]

#string to date format
df2['Fecha'] = pd.to_datetime(df2['Fecha'],infer_datetime_format=True)
df2 = df2.set_index(['Fecha'])
df2 = df2[["Tasa de desocupación "]]

# %%
plt.figure(figsize=(15,7))
plt.plot(df2["Tasa de desocupación "], color='#1f76b4')
plt.plot(np.exp(results_sa), color='darkgreen')

# %%
from sklearn.metrics import r2_score, mean_squared_error

r2 = r2_score(df2["Tasa de desocupación "], np.exp(results_sa))


print("R^2:", r2)

fig, ax = plt.subplots(figsize=(7, 2.5))
plt.plot(df2["Tasa de desocupación "],color="red",label="real")
plt.plot(np.exp(results_sa),color="blue",label="predicted")
plt.show()
print(f"Delta : {df2['Tasa de desocupación ']-np.exp(results_sa)}")
# Out:
# R^2: -2.7753794383238626
# Delta : Fecha
# 2023-02-01    0.269014
# 2023-03-01    0.482832
# 2023-04-01    0.272536
# dtype: float64

# %% [markdown]
# LSTM

# %%
import pandas as pd
#Importing Keras 
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import numpy as np
from keras.layers import LSTM
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

training_set=np.log(pd.read_csv("Datos_imputados_data_2.csv",index_col=["Fecha"])["Tasa de desocupación "][:-3])
print(training_set.tail())
training_set=training_set.values

from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
training_set=training_set.reshape(-1,1)
training_set=sc.fit_transform(training_set)
x_train=training_set[0:len(training_set)-1]
y_train=training_set[1:len(training_set)]
#print("x-train:\n",x_train[:5],"\ny-train:\n",y_train[:5])

x_train=np.reshape(x_train,(len(training_set)-1,1,1))

regressor=Sequential()
regressor.add(LSTM(70,activation="sigmoid",input_shape=(None,1)))
regressor.add(Dense(units=1))
regressor.compile(optimizer='adam', loss=tf.keras.losses.Huber())
regressor.fit(x_train,y_train,batch_size=32,epochs=200)

test_set=np.log(pd.read_csv("Datos_imputados_data_2.csv",index_col=["Fecha"])["Tasa de desocupación "][-3:])
real=test_set.values.reshape(-1,1)


inputs=real
inputs=sc.transform(inputs)
inputs=np.reshape(inputs,(3,1,1))
predicted=regressor.predict(inputs)
predicted=sc.inverse_transform(predicted)
# Out:
# Fecha
# 2022-09-01    2.084432
# 2022-10-01    2.075481
# 2022-11-01    2.073024
# 2022-12-01    2.062136
# 2023-01-01    2.084086
# Name: Tasa de desocupación , dtype: float64
# x-train:
#  [[0.57204312]
#  [0.51898836]
#  [0.55335389]
#  [0.49380563]
#  [0.47315109]]
# y-train:
#  [[0.51898836]
#  [0.55335389]
#  [0.49380563]
#  [0.47315109]
#  [0.46233469]]
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/200
# 5/5 [==============================] - 1s 11ms/step - loss: 0.0905
# Epoch 2/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0547
# Epoch 3/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0321
# Epoch 4/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0229
# Epoch 5/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0202
# Epoch 6/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0210
# Epoch 7/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0215
# Epoch 8/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0209
# Epoch 9/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0200
# Epoch 10/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0194
# Epoch 11/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0192
# Epoch 12/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0189
# Epoch 13/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0188
# Epoch 14/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0185
# Epoch 15/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0183
# Epoch 16/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0182
# Epoch 17/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0179
# Epoch 18/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0178
# Epoch 19/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0175
# Epoch 20/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0174
# Epoch 21/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0172
# Epoch 22/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0170
# Epoch 23/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0168
# Epoch 24/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0166
# Epoch 25/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0164
# Epoch 26/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0162
# Epoch 27/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0160
# Epoch 28/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0158
# Epoch 29/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0156
# Epoch 30/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0154
# Epoch 31/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0152
# Epoch 32/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0151
# Epoch 33/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0149
# Epoch 34/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0147
# Epoch 35/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0145
# Epoch 36/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0143
# Epoch 37/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0141
# Epoch 38/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0140
# Epoch 39/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0138
# Epoch 40/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0135
# Epoch 41/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0134
# Epoch 42/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0132
# Epoch 43/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0130
# Epoch 44/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0128
# Epoch 45/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0126
# Epoch 46/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0125
# Epoch 47/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0123
# Epoch 48/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0121
# Epoch 49/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0119
# Epoch 50/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0118
# Epoch 51/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0116
# Epoch 52/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0114
# Epoch 53/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0113
# Epoch 54/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0111
# Epoch 55/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0109
# Epoch 56/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0107
# Epoch 57/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0106
# Epoch 58/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0104
# Epoch 59/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0102
# Epoch 60/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0101
# Epoch 61/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0099
# Epoch 62/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0098
# Epoch 63/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0096
# Epoch 64/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0095
# Epoch 65/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0093
# Epoch 66/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0091
# Epoch 67/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0090
# Epoch 68/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0088
# Epoch 69/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0087
# Epoch 70/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0085
# Epoch 71/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 72/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0082
# Epoch 73/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 74/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0079
# Epoch 75/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0078
# Epoch 76/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0077
# Epoch 77/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0075
# Epoch 78/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0074
# Epoch 79/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0072
# Epoch 80/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0071
# Epoch 81/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0070
# Epoch 82/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0069
# Epoch 83/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0067
# Epoch 84/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0066
# Epoch 85/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0064
# Epoch 86/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0063
# Epoch 87/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0062
# Epoch 88/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0061
# Epoch 89/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0060
# Epoch 90/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0059
# Epoch 91/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0057
# Epoch 92/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0056
# Epoch 93/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0055
# Epoch 94/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0054
# Epoch 95/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0053
# Epoch 96/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0052
# Epoch 97/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0051
# Epoch 98/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0049
# Epoch 99/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0049
# Epoch 100/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0047
# Epoch 101/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0046
# Epoch 102/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0045
# Epoch 103/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0045
# Epoch 104/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0043
# Epoch 105/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0043
# Epoch 106/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0042
# Epoch 107/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0041
# Epoch 108/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0040
# Epoch 109/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0039
# Epoch 110/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0038
# Epoch 111/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 112/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 113/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0036
# Epoch 114/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0035
# Epoch 115/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0034
# Epoch 116/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033
# Epoch 117/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033
# Epoch 118/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0032
# Epoch 119/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 120/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 121/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0030
# Epoch 122/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0029
# Epoch 123/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0029
# Epoch 124/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0028
# Epoch 125/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0027
# Epoch 126/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0027
# Epoch 127/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0026
# Epoch 128/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0026
# Epoch 129/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0025
# Epoch 130/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0025
# Epoch 131/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0024
# Epoch 132/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0024
# Epoch 133/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0023
# Epoch 134/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0023
# Epoch 135/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 136/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 137/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 138/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 139/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 140/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 141/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 142/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0020
# Epoch 143/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 144/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0019
# Epoch 145/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 146/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 147/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 148/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 149/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 150/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 151/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 152/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017
# Epoch 153/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 154/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 155/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 156/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 157/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 158/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 159/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 160/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 161/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 162/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 163/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 164/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 165/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 166/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 167/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 168/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 169/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 170/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 171/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 172/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 173/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 174/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 175/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 176/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 177/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 178/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 179/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 180/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 181/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 182/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 183/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 184/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 185/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 186/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 187/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 188/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 189/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 190/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 191/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 192/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 193/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 194/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 195/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 196/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 197/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 198/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 199/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 200/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# 1/1 [==============================] - 0s 149ms/step

# %%
train_predict=regressor.predict(x_train)
train_predict=sc.inverse_transform(train_predict)
plt.plot(train_predict,color="red",label="train_predict")
plt.plot(sc.inverse_transform(y_train),color="blue",label="train_real")
plt.xlabel("Date")
plt.ylabel("Unemployed Number")
plt.title("Train Prediction")
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
plt.plot(real,color="red",label="real")
plt.plot(predicted,color="blue",label="predicted")
plt.xlabel("Date")
plt.ylabel("Unemployed Number")
plt.title("Test Prediction")
plt.legend()
plt.show()

# %%
# Calcular R^2
from sklearn.metrics import r2_score, mean_squared_error

r2 = r2_score(real, predicted)


print("R^2:", r2)


fig, ax = plt.subplots(figsize=(7, 2.5))
plt.plot(np.exp(real),color="red",label="real")
plt.plot(np.exp(predicted),color="blue",label="predicted")
plt.show()
# Out:
# R^2: 0.5226675984184552

# %%
print(f"Delta: {np.exp(real) - np.exp(predicted)}")
# Out:
# Delta: [[0.1046325 ]
#  [0.14299529]
#  [0.12940111]]
